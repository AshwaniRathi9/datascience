# %%
# Try:
# Except:
try:
  print(x)  # what code can trow an error/ error will be in TRY
except:
  print("There is no x") # After try, except will be executed
# Out:
# There is no x

# %%
try:
  print(x)
except:
  print("There is no x")
else:
  print("No error")
# Out:
# There is no x

# %%
try:
  print(x)
except:
  print("There is no x")
finally:
  print("Try and Except are executed")
# Out:
# There is no x
# Try and Except are executed

# %%
# it is example to show error
x = 10
if x < 20:
  raise Exception("There is a issue.... X is below 20")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-0e439e47d405> in <cell line: 2>()
#       1 x = 10
#       2 if x < 20:
# ----> 3   raise Exception("There is a issue.... X is below 20")
#
# Exception: There is a issue.... X is below 20

# %%
try:
  a = int(input("Enter num1: "))
  b = int(input("Enter num2: "))

  result = a / b
  print("Result", result)
except ZeroDivisionError:
  print("You have divided the number by Zero")
# Out:
# Enter num1: 4
# Enter num2: 2
# Result 2.0

# %%
# Type Error
try:
  x = "20"
  y = 10
  z = x + y
  print(z)
except TypeError:
  print("Data type mismatch")
# Out:
# Data type mismatch

# %%
try:
  a = int(input("Enter num1: "))
  b = int(input("Enter num2: "))

  result = a / b
  print("Result", result)

except ZeroDivisionError:
  print("You have divided the number by Zero")

except ValueError:
  print("Its integer but you enter float")
# Out:
# Enter num1: 4
# Enter num2: 0
# You have divided the number by Zero

# %%
try:
  a = int(input("Enter num1: "))
  b = int(input("Enter num2: "))

  result = a / b
  print("Result", result)

except ZeroDivisionError:
  print("You have divided the number by Zero")

except ValueError:
  print("Its integer but you enter float")
# Out:
# Enter num1: 5
# Enter num2: 5.6
# Its integer but you enter float

# %%
try:
  list1 = [11, 21, 31, 41]
  print(list1[4])

except IndexError:
  print("Wrong Index")
# Out:
# Wrong Index

# %%
# Key Error
try:
  my_dict = {"name": "Tony", "age": "23"}
  print(my_dict["city"])

except KeyError:
  print("Key not found")
# Out:
# Key not found

# %%
try:
  my_dict = {"name": "Ashwani", "rollno": "23", "school": "Maples Academy"}
  print(my_dict["school"])

except KeyError:
  print("Key not found")
# Out:
# Maples Academy

# %%
try:
  file_location = "my_file.txt"
# Looking for the file and setting the permission ( r = read, w = write)
  with open(file_location, "r") as file:
    content = file.read()

except FileNotFoundError:
  print("File you are looking for is not there")
# Out:
# File you are looking for is not there

# %%
try:
  file_location = "file123.txt"

  with open (file_location, "w") as file:
    content = file.read()

except IOError:  # IO = Input and Output Eerror
  print(f"unable to read this file '{file_location}'.")
# Out:
# unable to read this file 'file123.txt'.

# %%
try:
  import library123

except ImportError:
  print("Particular library Missing")
# Out:
# Particular library Missing

# %%
try:
  import physics

except ImportError:
  print("It is not math")
# Out:
# It is not math

# %%
try:
  result = 500 ** 10

except OverflowError:
  print("Too big calculation")
else:
  print(result)
# Out:
# 976562500000000000000000000

# %%
try:
  result = 12 ** 10

except OverFlowError:
  print("Too big calculation")

else:
  print(result)
# Out:
# 61917364224

# %%
try:
  print(" Tony is a good boy")

except SyntaxError:
  print("Please check the syntax")
# Out:
#  Tony is a good boy

# %% [markdown]
# 18/06/23

# %%
# Raise is used to call a particular exception

# %%
class MyCustomer(Exception):
  pass

# %%
class checkAge(Exception):
  "Raised when the input age is less than 18"
  pass

# %% [markdown]
# **Logging:**

# %%
# Logging deals with code (error, warning message, debug, info)
# Debug
# info
# waring
# error
# critical error

# logging event
# logging.basicConfig(level=logging.DEBUG)
# logging.debug("This is debug message")
# logging.info("This is information message")
# logging.warning("This is warning message")
# logging.error("This is error message")
# logging.critical("This is CRITICAL error message")

# %%
import logging
logging.basicConfig(level=logging.DEBUG)

def add(x,y):
  logging.debug("varibles are %s and %s", x,y)
  return x + y

add(2,4)
# Out:
# 6

# %%
import logging
logging.basicConfig(level=logging.DEBUG)

def add(x,y):
  logging.debug("varible are %s and %s", x, y)
  # %s is used for as string place holder because you are printing the variable values also 2 and 3 i:e use %s.
  # level is used for Event(debug, warning, error).
  return x + y
add(23,4)
# Out:
# 27

# %%
import logging
logging.basicConfig(level=logging.INFO)

def diff(x,y):
  logging.info("This is a infomation", x, y)
  return x - y

diff(5,2)
# Out:
# 3

# %%
import logging

logging.basicConfig(level=logging.INFO)

def login123(User):
  logging.info("User name is %s", User)

login123("Admin")
# Out:
# WARNING:root:User name is Admin

# %%
import logging
logging.basicConfig(level=logging.WARNING)

def account(id):

  if id < 2343:
    logging.warning("Sorry you have enter wrong id is %s", id)

account(232)
# Out:
# WARNING:root:Sorry you have enter wrong id is 232

# %%
import logging
logging.basicConfig(level=logging.ERROR)

def name(user):

  if user < 5656:
    logging.error("User number is wrong  %s", user)

name(4545)
# Out:
# ERROR:root:User number is wrong  4545

# %%
import logging
logging.basicConfig(level=logging.CRITICAL)

def file(user):
  logging.critical("Python file is save in format in .ipynb: %s", user)

file(".txt")
# Out:
# CRITICAL:root:Python file is save in format in .ipynb: .txt

# %%
import logging
logging.basicConfig(level=logging.debug)

def first(name):
  logging.debug("My first name is %s", name)

first("Tony")

# %%
import logging
logging.basicConfig(level=logging.ERROR)

def login123(user):
  logging.error("User name is %s", user)

login123("Admin")
# Out:
# ERROR:root:User name is Admin

# %%
import logging
logging.basicConfig(level=logging.WARNING)

def My_Balance(Amount):
  if Amount < 20000:
    logging.warning("Sorry you have low balance, your balance is %s,", Amount)

My_Balance(10000)
# Out:
# WARNING:root:Sorry you have low balance, your balance is 10000,

# %%
import logging

logging.basicConfig(level=logging.ERROR)

def DivideByZero(a,b):
  try:
    result = a / b
  except ZeroDivisionError:
    logging.error("Division By Zero")
  else:
    print(result)

DivideByZero(5,0)
# Out:
# ERROR:root:Division By Zero

# %%
import logging
logging.basicConfig(level=logging.CRITICAL)

def LetUsCheckSystem(sys):
  if sys != 'OK':
    logging.critical("System failed to boot: %s", sys)

LetUsCheckSystem("You need to handle this issue")
# Out:
# CRITICAL:root:System failed to boot: You need to handle this issue

# %%
import os
print(os.getcwd())
# Out:
# /content
