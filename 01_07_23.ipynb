# %% [markdown]
# **Object Oriented programming language(Oops)**
#
#    **Classes**
#    - it is blueprint

# %%
# Empty class
class Person:
  pass

# %%
# object is a blueprint copy
# person1 is a object or instance

person1=Person()

# %%
print(person1)

# %%
# Attributes
# I create a attribute is name

person1.name="Tony"

print(person1.name)
# Out:
# Tony

# %%
# define a class person
# we use __init__ function i;e basically called as constructor.
# attribute are in define class are self, name1, last_name1
# self is reffering to this intanse

class Person:
  def __init__(self,name1,last_name1):
    self.name=name1
    self.last_name=last_name1

# %%
person=Person("Ashwani", "Rathi")

# %%
print(person.name)
print(person.last_name)
# Out:
# Ashwani
# Rathi

# %%
person2=Person("Tony", "Rathi")

print(person2.name)
# Out:
# Tony

# %%
class Person:
  def __init__(self,first_name,last_name):
    self.first_name=first_name
    self.last_name=last_name

  def __str__(self):
    return "The first name is {} and the last name is {}".format(self.first_name,self.last_name)

# %%
person1=Person("Ashwani", "Rathi")
print(person1)
# Out:
# The first name is Ashwani and the last name is Rathi

# %%
# Class representing a to do list

class todoList:
  def __init__(self,owner):
    self.owner=owner
    self.tasks=[]

  def add_tasks(self,task):
    self,tasks.append(task)

  def complete_taks(self,task):
    if task in self.tasks:
      print(f"Task {task} completed")
    else:
      print("The task is not found")

  def display_tasks(self):
    print(f"The todo task of {self,owner}:")
    for task in self.tasks:
      print(task)

# %%
class BankAccount:
  def __init__(self,account_number,account_holder_name,balance=0):
    self.account_number=account_number
    self.account_holdetr_name=account_holder_name
    self.balance=balance

  def

# %%
person1=BankAccount('1234',"Tony Rathi")
print(person1)

# %%
class Laptop:
  def __init__(self,model,brand,ram):
    self.model=model
    self.brand=brand
    self.ram=ram

  def power_off(self) :
    print(f"This {self.brand} {self.model} is now switched on")

  def power_on(self):
    print(f"This {self.brand} {self.model} is now switched off")

# %%
dell=Laptop("A54","Dell","4 gb")
print(dell)

# %%
dell.power_off()
# Out:
# This Dell A54 is now switched on

# %%
dell.power_on()
# Out:
# This Dell A54 is now switched off

# %%
class Mobilephone:
  def __init__(self,brand,model,ram,price):
    self.brand=brand
    self.model=model
    self.ram=ram

  def make_calls(self,number):
    print(f"calling {number} with {self.brand} and {self.brand}")

  def send_message(self,number):
    print(f"sending message to {number} : {message}")

  def end_call(self,number):
    print(f"call is disconnected with {number}")

# %%
samsung=Mobilephone("Samsung","galaxy A5","12 gb","75000")
print(samsung)

# %%
samsung.make_calls
# Out:
# <bound method Mobilephone.make_calls of <__main__.Mobilephone object at 0x7f1519d631f0>>

# %%
samsung.send_message
# Out:
# <bound method Mobilephone.send_message of <__main__.Mobilephone object at 0x7f1519d631f0>>

# %%
samsung.end_call
# Out:
# <bound method Mobilephone.end_call of <__main__.Mobilephone object at 0x7f1519d631f0>>

# %%
class Car:
  def __init__(self,brand,model,colar):
    self.brand=brand
    self:model=model
    self:colar=colar

  def start_engine(self):
    print(f"the {self.color} {self.brand} {self.model} is starting")

  def stop_engine(self):
    print(f"the {self.color} {self.brand} {self.model} is stop")

# %%
baleno=Car("maruti","2021","grey")

# %%
baleno.start_engine
# Out:
# <bound method Car.start_engine of <__main__.Car object at 0x7f1519d61030>>

# %%
baleno.stop_engine
# Out:
# <bound method Car.stop_engine of <__main__.Car object at 0x7f1519d61030>>

# %% [markdown]
# 02/07/23

# %% [markdown]
# **Inderitance** **CLasses**

# %%
class Person:
  def __init__(self,name):
    self.name=name

  def display_info(self):

# %%
# Create a vehicle class with attributes brand and method start
#Create s child class Bicycle and ca

class Bicycle(Vehicle):
  def __init__(self,model,brand):
    super().__init__()
    self.model=model
    self.brand=brand

  def start(self):
    print(f"the {self.model} {self.brand} is starting")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-22d7c0769b3f> in <cell line: 4>()
#       2 #Create s child class Bicycle and ca
#       3
# ----> 4 class Bicycle(Vehicle):
#       5   def __init__(self,model,brand):
#       6     super().__init__()
#
# NameError: name 'Vehicle' is not defined

# %%
bicycle=Bicycle("")

# %%
class Vehicle:
  def __init__(self,brand):
    self.brand=brand

  def start(self):
    print(f"the {self.brand} is starting")

# %%
class Dog(Animal):
  def __init__(self,name):
    super().__init__(name)
    self.name=name


  def display_info(self):
    super(f"{self.name} ")
