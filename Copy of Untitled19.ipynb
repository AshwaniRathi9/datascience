# %%
class demo:
  def __init__(self):
    print("i am in the init function")
    print(f"here is value of self {id(self)}")

# %%
obj1=demo()
# Out:
# i am in the init function
# here is value of self 134528193878944

# %%
print(id(obj1))
# Out:
# 134528193878944

# %%
class demo:
  city="bhopal"

  @classmethod
  def test(cls):
    print("i am working as a class method")
    print(f"here is a address of cls {id(cls)}")
    print(demo.city)
    print(demo.name)

  @staticmethod
  def test2():
    print("here i am working with static method")
    #print(cls.city)


  def __init__(self,name):
    self.name=name

# %%
mohit=demo("mohit")

# %%
mohit.name
# Out:
# 'mohit'

# %%
demo.name="kunal"

# %%
demo.name
# Out:
# 'kunal'

# %%
obj4=demo("pooja")

# %%
obj4.name
# Out:
# 'pooja'

# %%
demo.name
# Out:
# 'kunal'

# %%
demo.city
# Out:
# 'bhopal'

# %%
obj4.city
# Out:
# 'bhopal'

# %%
demo.test()
# Out:
# i am working as a class method
# here is a address of cls 42371840
# bhopal
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-b44f79dfc677> in <cell line: 1>()
# ----> 1 demo.test()
#
# <ipython-input-50-0f3691f20fcb> in test(cls)
#       7     print(f"here is a address of cls {id(cls)}")
#       8     print(demo.city)
# ----> 9     print(demo.name)
#      10
#      11   @staticmethod
#
# AttributeError: type object 'demo' has no attribute 'name'

# %%
mohit.test2()
# Out:
# here i am working with static method
# bhopal

# %%
rahul=demo("rahul")

# %%
demo.test()
# Out:
# i am working as a class method
# here is a address of cls 42738784
# bhopal

# %%
id(demo.city)
# Out:
# 134528193792560

# %%
sunny=demo("sunny")

# %%
sunny.name
# Out:
# 'sunny'

# %%
rohit=demo("rohit")

# %%
rohit.name
# Out:
# 'rohit'

# %%
sunny.city
# Out:
# 'bhopal'

# %%
rohit.city
# Out:
# 'bhopal'

# %%
id(sunny.city)
# Out:
# 134528193792560

# %%
id(rohit.city)
# Out:
# 134528193792560

# %%
def greet(text):
  return text.upper()

# %%
greet("hello good morning")
# Out:
# 'HELLO GOOD MORNING'

# %%
test=greet

# %%
test("hi good evening")
# Out:
# 'HI GOOD EVENING'

# %%
def greet(text):
  return text.upper()

# %%
def shout(text):
  return text.lower()

# %%
def master(func):
  output=func("Hi Good Morning HOW are you")
  print(output)

# %%
master(greet)
# Out:
# HI GOOD MORNING HOW ARE YOU

# %%
master(shout)
# Out:
# hi good morning how are you

# %%
def create_add(x):
  def add(y):
    print(x+y)
  return add

# %%
var=create_add(10)

# %%
var(20)
# Out:
# 30

# %%
def hello_decorator(func):
  def inner(a,b):
    print("before execution")
    value=func(a,b)
    print("after execution")
    return value
  return inner

# %%
@hello_decorator
def sum_two_number(a,b):
  print("inside this function")
  return a+b

# %%
sum_two_number(10,20)
# Out:
# before execution
# inside this function
# after execution
# 30
