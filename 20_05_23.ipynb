# %% [markdown]
# Basic Python

# %% [markdown]
# **Keywords:**
#
# Here are the points related to keywords in Python
#   - Definition: Keywords in Python are reserved words that cannot be used as ordinary identifiers.
#   - Immutualility: Keywords are immutable.
#   - Case sensitivity: keywords are case sensitivity.
#   - Total number: There are 35  Keywords.
#   - Lists of Keywords: 'False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield'.

# %%
# What is a package or libaries: It is a box and In the box you have many tools or function.
# Math: Addition, Substraction, multi, div.
# Python has many Packages.


# pip insult keyword
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
none = 10
print(none)
# Out:
# 10

# %%
False1 =12
print(False1)
# Out:
# 12

# %%
#None = 10
# Capital is different small letter
none = 10
print(none)
# Out:
# 10

# %%
import math
a = math.sqrt(9)
print(a)
# Out:
# 3.0

# %%
import math
result = math.sqrt(10)
print(result)
# Out:
# 3.1622776601683795

# %%
import math
result = math.sqrt(81)
print(result)
# Out:
# 9.0

# %% [markdown]
# **Identifiers**
#
#     Here are the points related to Ientifiers in Python
#
#      - Definition: An identifiers is a name given to entities likes class, function, varibles, etc.
#      - Syntax: Identifiers can be combination of letter in lower case or upper case or an underscore.
#      - No digit: they must start with a letter or the underscore character, but not with a digit.
#      - Case Sensitive: Identifier in Python are case senseitive.
#      - No special character: Identifier cannot have special; character such as !,@, $, #, %, ^, &

# %%
marks = 50
Marks = 76
MARKS = 45
print(marks,
      Marks,
      MARKS)
# Out:
# 50 76 45

# %%
marks = 50

print(marks)
# Out:
# 50

# %%
marks = 60
Marks = 75
print(marks)
print(Marks)
# Out:
# 60
# 75

# %%
marks = 19
print(marks)
# Out:
# 19

# %%
_10marks = 91
print(_10marks)
# Out:
# 91

# %% [markdown]
# **Comments**
#
#     Here are the points related to Comments in Python
#
#      - Definition: A common in Python is a piece of text in your code that is not executed.
#      - Single line comment: Python use the hash(#) to donate a comment.
#      - Multi line comment: Python does not have a specific syntax for multi lines comment
#      - Docstring or Documentation: Docstring are a type of comment used to explain the purpose of a function or a class

# %%
# Single line comment
# Add two number

a = 3
b = 4
c = a + b
print(c)
# Out:
# 7

# %%
# Multiline comment

# value of a is 3
# value of b is 4

a = 3
b = 4
c = a + b
print(c)
# Out:
# 7

# %%
def number(a,b):
  '''
  Parameters:
  a(int): The first varible
  b(int): The second varible

  Return:
  int: which is the sum of a and b
  '''
  return a + b

# %%
print(number.__doc__)
# Out:
#   Parameters:
#   a(int): The first varible
#   b(int): The second varible
#
#   Return:
#   int: which is the sum of a and b

# %% [markdown]
# **Indentions**
#
#       - Importance: In Python, indention is just not for readability. It's a part of the syntax and is used to indcate a block of core.
#       - space usages: Python uses indentions to define the scope of loops, function, classes, etc.
#       - Colon: Usally, a colon(:) at the end of the lines is followed by an idnetion block

# %%
# Incorrect use of indention

if True:
  print("This is True!")
# Out:
# This is True!

# %%
if 2 > 5:
  print("This is true")

# %%
if 2 < 0:
  print("This is True")

# %%
if True:
  print("This is False!")
# Out:
# This is False!

# %%
# Error: expected an indented block
if True:
  print("This is True")

# Error: expected an indented block

for i in range(3):
  print(i)

# Error: expected an indented block

def hello():
  print("Hello, World")

# Error: expected an indented block

while False:
  print("This won't print")
# Out:
# This is True
# 0
# 1
# 2

# %% [markdown]
# **Statements**
#
#         - Definition: A statement in python is a logical instruction in the python interpreter can read execute.
#         - Types: Python inducates several types of statement including assignment statement, conditional statement, looping statment, etc.

# %%
# conditional statement

x = 2
if x >=0:
  print("Positive Number")
# Out:
# Positive Number

# %%
x = -3
if x >= -13:
  print("Negative Number")
# Out:
# Negative Number

# %% [markdown]
# Multi lines Statement: In Python, end of a end statement is marked by a newline character. But we can make a statement extend over multiple lines with the line
# continuation character(/), {}, [], (), or string.

# %%
s = (1 - 2 + 3 + 4
     + 5 + 6 + 7)
print(s)
# Out:
# 24

# %%
a = (1+2+3
+1+2+3/
+1+2+3/
+1+2+3)
print(a)
# Out:
# 22.0

# %%
a = 1 + 2 + 3 \
 + 4 + 5 + 6
print(a)
# Out:
# 21

# %% [markdown]
# **Variables**
#
#
#       - Definition: In Pytho, a varible is a location used to store data in memory.
#       - Declaration and assignment: Varibles are declared by writing the varibles name and assigning it in value using the equal sign(=).

# %%
a = 5

# %% [markdown]
# **Dynamic-Variable**
#
#
#       - Python is dynamically typed, which means that you to declare the type of a varibles when you create one.
#       - You can even change the type of dtat held by a varible at any time.

# %%
# percentage
# where you do not have Dymanic Typing
# int percentage

percentage = 90
print(percentage)
# Out:
# 90

# %% [markdown]
# **Data Types in Python**
#
#         - Integer are whole number, without a fractional component.
#         - They can be positive or negative

# %%
x = 5

# %% [markdown]
# **Floats:**
#
#      -Floats represent real number and are within a decimal point.

# %%
x = 7.78

# %% [markdown]
# **Strings**:
#
#     - String in python are sequences of character data.
#     - They are creted by enclosing charcter in quotes.

# %%
nm1 = "Ashwani"
nm1 = 'Tony'

# %% [markdown]
# **Lists**:
#
#     - A list in Python is a ordered collection of item.
#     - List are similiar to arrays in other language, but with additional functionally.
#
# **Mutable**:
#
#     - Lists are mutable, which means their element can changed afte they craeted.
#
# **Creation**:
#
#     - A list is created by placing item inside square bracket[]

# %%
list = ['ashwani', 'romy', 'annu']
print(list)
# Out:
# ['ashwani', 'romy', 'annu']

# %%
fruit = ['apple', 'banana', 'grapes']
print(fruit)
# Out:
# ['apple', 'banana', 'grapes']

# %% [markdown]
# **Hetrogeneous elements:**
#
#     - A list can contain element of different types: integers, floats, strings and even other lists or tuples.

# %%
hetro_myList = [1, 'alice', ['apple', 'grapes', 'pineapple']]
print(hetro_myList)
# Out:
# [1, 'alice', ['apple', 'grapes', 'pineapple']]

# %% [markdown]
# **Tuples**:
#
#     - A tuple in python is similiar to a list. It's and ordered collection of item.
# **Immutable:**
#
#     - Tuples are immutable, which means their element cannot be changed after they created.
#
# **Creation**:
#
#     - A tuples can create by placing item inside parenthesis () , separated commas.

# %%
my_list = [1, 2, 3, 4, 5]
# mutable

my_tuple = (1, 2, 3, 4, 4, 5, 6)
# Immutable

print(my_tuple)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# **Hetrogeneous** **Element:**
#
#     - Like lists, a tuple can also contain element of different types: Integers, float, string, and even other tuples or lists.

# %%
hetro_myList = (1, 'alice', ['apple', 'grapes', 'pineapple'])
print(hetro_myList)
# Out:
# (1, 'alice', ['apple', 'grapes', 'pineapple'])

# %% [markdown]
# **Dictonaries**:
#
#     - A dictonaries in python ia an ordered collection of item.
#     - Each item stored in a dictonaries has a key and value.
#
# **Mutable**:
#
#     - Dictnaries are mutable, which means you can change their element.
#
# **Creation**:
#
#     - A dictonaries is created by placing item inside the cruly bracket {}.

# %%
Dict1 = {'name': 'Ashwani', 'age':'25', 'school': 'maple' }
print(Dict1)
# Out:
# {'name': 'Ashwani', 'age': '25', 'school': 'maple'}

# %%
my_dict = {"Name": 'ashwani', "rollno": "20", "school": "Maples academy"}
print(my_dict)
# Out:
# {'Name': 'ashwani', 'rollno': '20', 'school': 'Maples academy'}

# %% [markdown]
# **Hetrogeneous** **Element**:
#
#     - Keys and value in dictonary can be any type.
#     - Value can be heterogeneous.
#     - but key should be of an immutable type

# %%
hetro_myList = {"ashwani", "1", "mango", 'grapes', 'carrot'}
print(hetro_myList)
# Out:
# {'mango', '1', 'ashwani', 'grapes', 'carrot'}

# %% [markdown]
# **Sets**:
#
#     - A sets ia an unordered collection of items where every element is unique.
#     - Sets are Mutable.
#     - Sets are hetrogenous.

# %%
color = {"blue", 'red', "green", 'yellow'}
print(color)
# Out:
# {'yellow', 'red', 'green', 'blue'}

# %%
my_dict = {"name": "Maples Academy", "location": "Budhana"}
print(my_dict)
# Out:
# {'name': 'Maples Academy', 'location': 'Budhana'}

# %% [markdown]
# **Standard Input and Output**:
#
#     Standard Output:
#         - This is typical the terminal wher the program is run.
#         - When a program wants to output some information.
#         - It is typically print to the standard output.
#         - Python provide print() function to send data to standard output.

# %%
a = 777
print(a)
# Out:
# 777

# %% [markdown]
# Standard Input:
#
#     - This is usually the keyboard, but it can also be data coming from a file.
#     - Python provide print() function to send data to standard input.

# %%
name = input("Enter your name")
print(f"How are you", {name})
# Out:
# Enter your name tony
# How are you {' tony'}

# %% [markdown]
# 21/05/23

# %%
# What are package ?
import keyword
print(ketword.kwlist)

# %%
import math
result = math.sqrt(20)
print(result)
# Out:
# 4.47213595499958

# %%
import math
result = math.sqrt(2)
print(result)
# Out:
# 1.4142135623730951

# %%
from math import sqrt
result = sqrt(81)
print(result)
# Out:
# 9.0

# %%
marks1 = 123
Marks1 = 232
tot = marks1 + Marks1
print(tot)
# Out:
# 355

# %% [markdown]
# Comment

# %%
# You can start variable name using
_age = 21
print(_age)
# Out:
# 21

# %%
"""
you cannot start a variable using 0-9
you can use digit anywhere, avoiding at the start

"""

__age21 = 45
print(__age21)
# Out:
# 45

# %%
x = 5
# if x is greater than 2, In this case i have print "Positive number"
if x > 2:
  print("positive number")
# Out:
# positive number

# %%
x = 5
# if x is greater than 2, In this case i have print "Positive number"
if x > 2:
  print("positive number")


if x > 4:
  print("Positve number and it is more then 4")
# Out:
# positive number
# Positve number and it is more then 4

# %%
# integer, float, string, ....

 a = 10 # it is integer

 b = 12.34 # it is float

 nm = "Tony" # it is string

# %%
a = 10.34
print(type(a))
# Out:
# <class 'float'>

# %%
a = 12
print(type(a))
# Out:
# <class 'int'>

# %%
c = "Ashwnai"
print(type(c))
# Out:
# <class 'str'>

# %%
List = [1, "ashwani", 12.25]
print(type(List))
# Out:
# <class 'list'>

# %%
a = 10
b = 12.45
c = "Ashwani"
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# List
# list are mutable
fruits = ["apple", "orange", "grapes"]
print(fruits)

fruits = ["apple", "cherry", "grapes"]
print(fruits)
# Out:
# ['apple', 'orange', 'grapes']
# ['apple', 'cherry', 'grapes']

# %%
print(fruits)
# Out:
# ['apple', 'orange', 'grapes']

# %%
# tuple
# tuple are immutable
fruits = ("apple", "grapes", "orange")
print(fruits)
# Out:
# ('apple', 'grapes', 'orange')

# %%
# tuple
stock = ("carrot", "ladyfinger", "ginger")
print(stock)
# Out:
# ('carrot', 'ladyfinger', 'ginger')

# %%
my_dict = {"name": "Ashwani", "subject": "Math", "marks": "89"}
print(my_dict)
# Out:
# {'name': 'Ashwani', 'subject': 'Math', 'marks': '89'}

# %%
school= {"class A": "nursary", "class B": "LKG", "clas C": "UKG"}
print(school)
# Out:
# {'class A': 'nursary', 'class B': 'LKG', 'clas C': 'UKG'}

# %%
# sets
s1 = {1,2,3,4,5,6}
s2 = {1,2,3,4,5,6,7,8,9}
print(s1)
print(s2)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
score = 85
if score >= 90:
  print("excellent")
elif score >= 80:
  print("good")
elif score >= 70:
  print("average")

else:
  print("performance not good, keep hard studies")
# Out:
# good

# %%
for i in range (5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (2, 5):
  print(i)
# Out:
# 2
# 3
# 4

# %%
for i in range (2, 20, 3):
  print(i)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17

# %%
flist = ["Apple",'banana','orange']
for fruit in flist:
  print(fruit)
# Out:
# Apple
# banana
# orange

# %%
country = ['India','USA','UK']
for CT in country:
  print(CT)
# Out:
# India
# USA
# UK

# %%
class1 = ['Ashwani','Ujjawal','Romy']
for student in class1:
  print(student)
# Out:
# Ashwani
# Ujjawal
# Romy

# %%
country = ['India','USA','UK']
for index in range(len(country)):
  print(country[index])
# Out:
# India
# 3
# USA
# 3
# UK
# 3

# %%
country = ['India','USA','UK']
for index in range(len(country)):
  print(len(country))
# Out:
# 3
# 3
# 3

# %%
a =10
result = a>>2
print(result)
# Out:
# 2

# %%
a = 10
b = 4
print(a^b)
# Out:
# 14

# %%
a = 10
b = 15
print(a&b)
# Out:
# 10

# %%
a = 105
b = 1
print(a|b)
# Out:
# 105

# %%
a = 10
b = 20
print(a>b)
# Out:
# False

# %%
rows = 5
for i in range(rows):
  for j in range(i+1):
    print("*", end=" ")
  print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
count = 5
while count <= 5:
  print(count)
  count += 1
# Out:
# 5

# %%
text = ''
while text !='quit':
  text = input("Enter a word")
  print("You entered:", text)
# Out:
# Enter a wordAshwni
# You entered: Ashwni
# Enter a wordAshwani
# You entered: Ashwani
# Enter a word RAThi
# You entered:  RAThi
# Enter a word quit
# You entered:  quit
# Enter a wordquit
# You entered: quit
