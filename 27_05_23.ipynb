# %% [markdown]
# **Standard Input and Output**

# %%
# Standard Input
a = 23
b = 23
t = a + b
print(t)
# Out:
# 46

# %% [markdown]
# **Operators:**

# %%
# Arimetric Operation is a mathmatics operator(+, -, *, /, //, **, %)
a = 20
b = 30

print(a + b)
print(a - b)
print(b / a)
print(a * b)
print(a ** b)
print(b // a) # floor division method
print(b % a)
# Out:
# 50
# -10
# 1.5
# 600
# 1073741824000000000000000000000000000000
# 1
# 10

# %%
a = 20
b = 10
print(a / b)  # division method
print(a // b) # floor divison method
# Out:
# 2.0
# 2

# %%
# Modulas Operator(%)
# give a remainder
# how many times 4 will be divied from 30 = 4 and remaining remaider is 2
a =30
b = 4
print(a % b)
# Out:
# 2

# %%
# Exponential operator

a = 2
b = 2
print(a ** b) # 2 * 2 = 4
# Out:
# 4

# %%
# 2 * 2 * 2 = 8
# 3 * 3 * 3 = 27

a = 2
b = 3
print(a ** b)
# Out:
# 8

# %%
# 2 * 2 * 2 * 2 = 16
a = 2
b = 4
print(a ** b)
# Out:
# 16

# %%
# Comparision operator
# True, False
# Equal condition (==)
# Not Equal condition (!=)
# Greater than sign (>)
# Smaller than sign (<)
# Greater than sign Equal (>=)
# Smaller than sign (<=)
a = 10
b = 10
print(a == b)
# Out:
# True

# %%
a = 10
b = 10
print(a != b)
# Out:
# False

# %%
a = 10
b = 20
print(a < b)
# Out:
# True

# %%
a = 10
b = 20
print(a > b)
# Out:
# False

# %%
a = 100
b = 20
print(a >= b)
# Out:
# True

# %%
a = 10
b = 200
print(a >= b)
# Out:
# False

# %%
# Logical operators

# There are three types of operators are: AND, OR, and NOT

# We apply for a job : two condition are there : 1: more than 60% marks, and 2: you should have CS and IT.
#------------------------AND---------------------------------
#Tom he has 75% and he is from Arts = Tom will out
# Alice she has 61% and she is from CS = Alice will go for interview

# We apply for a job : two condition are there : 1: more than 60% marks, and 2: you should have CS and IT.
#------------------------OR---------------------------------
#Tom he has 75% and he is from Arts
# Alice she has 61% and she is from CS
# Both Alice and Tom will give the interview

#--------------------NOT---------------------------------
# Oppsite to what you have

a = True
b = True
print(a and b)
print(a or b)
print(not b)
# Out:
# True
# True
# False

# %%
a = False
b = True
print(a and b)
# Out:
# False

# %%
a = False
b = True
print(a or b)
# Out:
# True

# %%
a = False
b = True
print(not b)
# Out:
# False

# %%
# Bitwise Operators

# Bitwise operator deals with Binary numbers
