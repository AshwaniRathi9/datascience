# %%
def introduction():
  print("Ashwani")

introduction("Tony")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-fd4a8b2a6620> in <cell line: 4>()
#       2   print("Ashwani")
#       3
# ----> 4 introduction("Tony")
#
# TypeError: introduction() takes 0 positional arguments but 1 was given

# %%
def chapter():
  print("There are nine chapter are there in the book")

chapter()
# Out:
# There are nine chapter are there in the book

# %%
def ch
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-5e80f64c193a> in <cell line: 4>()
#       2   print("it")
#       3
# ----> 4 intro("is")
#
# TypeError: intro() takes 0 positional arguments but 1 was given
